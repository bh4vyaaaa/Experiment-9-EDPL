# %% [markdown]
# <a href="https://colab.research.google.com/github/bh4vyaaaa/Experiment-9-EDPL/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Experiment 9
# ## Introduction to Pandas
# ### Bhavya Pandya
# ### E&TC A1
# ### 25070123139

# %% [markdown]
# ### Panda :- Panel Data
# ### Used for structured data manipulation and analysis
# ### Exploratory Data Analysis
# ### and Data Cleaning

# %%
import pandas as pd
s = pd.Series([100,200,300,400,500])
s
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# 4    500
# dtype: int64

# %%
# Creating Dataframe
data = {
    "Name" : ["Bhavya","Ansh", "Shreyanshu"],
    "Age" : [18,18,18]
}
df = pd.DataFrame(data)
df
# Out:
#          Name  Age
# 0      Bhavya   18
# 1        Ansh   18
# 2  Shreyanshu   18

# %%
df.head()
df.tail()
# Out:
#          Name  Age
# 0      Bhavya   18
# 1        Ansh   18
# 2  Shreyanshu   18

# %%
# Find the structure of the dataframe
df.shape
# Out:
# (3, 2)

# %%
df.size
# Out:
# 6

# %%
df.ndim
# Out:
# 2

# %%
# display coloumn names
df.columns
# Out:
# Index(['Name', 'Age'], dtype='object')

# %%
df.dtypes
# Out:
# Name    object
# Age      int64
# dtype: object

# %%
# Access Indivisual Coloumn
df["Name"]
# Out:
# 0        Bhavya
# 1          Ansh
# 2    Shreyanshu
# Name: Name, dtype: object

# %%
df.loc[1]
# Out:
# Name    Ansh
# Age       18
# Name: 1, dtype: object

# %%
# Add a new Coloumn
df["Gender"] = ["Man","Man","Man"]

# %%
df
# Out:
#          Name  Age Gender
# 0      Bhavya   18    Man
# 1        Ansh   18    Man
# 2  Shreyanshu   18    Man

# %%
# Update Data In the Dataframe
# change age of shreyanshu to 19
df.loc[2,"Age"] = 19

# %%
df
# Out:
#          Name  Age Gender
# 0      Bhavya   18    Man
# 1        Ansh   18    Man
# 2  Shreyanshu   19    Man

# %%
# Delete a Coloumn
df.drop("Gender",axis=1,inplace=True)
df
# Out:
#          Name  Age
# 0      Bhavya   18
# 1        Ansh   18
# 2  Shreyanshu   19

# %%
# Perform Basic Statistical Analysis
mean1=df["Age"].mean()
mean1
# Out:
# np.float64(18.333333333333332)

# %%
df["Age"].median()
df
# Out:
#          Name  Age
# 0      Bhavya   18
# 1        Ansh   18
# 2  Shreyanshu   19

# %%
df["Age"].min()
df
# Out:
#          Name  Age
# 0      Bhavya   18
# 1        Ansh   18
# 2  Shreyanshu   19

# %%
# Apply Conditon (Filtering)
# Display Name with age more than 18
df[df["Age"]>18]
# Out:
#          Name  Age
# 2  Shreyanshu   19
